# %%
import random

# Part A - Machine Initialization

machines = ['A', 'B', 'C']
M = 3
N_play = 10
epsilon = 0.2

# Part B - Initialize N, R and Q

N = [0, 0, 0]
R = [0, 0, 0]
Q = [0.0, 0.0, 0.0]

total_reward = 0

# Part C, D and E
# ε-Greedy Decision, Reward and Q Update

for play in range(1, N_play + 1):
    r = random.random()
    if r < epsilon:
        selected_index = random.randint(0, M - 1)
        decision = "Exploration"
    else:
        max_q = max(Q)
        best_machines = [
            i for i in range(M)
            if Q[i] == max_q
        ]
        selected_index = random.choice(best_machines)
        decision = "Exploitation"
    selected_machine = machines[selected_index]
    print("\nPlay", play)
    print("Random number:", round(r, 4))
    print("Decision:", decision)
    print("Play with machine", selected_machine)

    # Part D - Reward Collection

    reward = float(input("Enter reward: "))

    # Part E - Update N, R and Q

    N[selected_index] += 1
    R[selected_index] += reward
    Q[selected_index] = (
        Q[selected_index]
        + (1 / N[selected_index])
        * (reward - Q[selected_index])
    )
    total_reward += reward
    print("Updated Q-value:",
          round(Q[selected_index], 4))

# Part F - Display Final Results

print("\n====================================")
print("FINAL RESULTS")
print("====================================")
print("\nMachine\tN\tR\tQ")
for i in range(M):
    print(
        machines[i],
        "\t",
        N[i],
        "\t",
        R[i],
        "\t",
        round(Q[i], 2)
    )
print("\nTotal reward after 10 plays:",
      total_reward)
# Out:
# Play 1
# Random number: 0.0941
# Decision: Exploration
# Play with machine B
# Enter reward: 3
# Updated Q-value: 3.0
#
# Play 2
# Random number: 0.1543
# Decision: Exploration
# Play with machine C
# Enter reward: 6
# Updated Q-value: 6.0
#
# Play 3
# Random number: 0.7424
# Decision: Exploitation
# Play with machine C
# Enter reward: 3
# Updated Q-value: 4.5
#
# Play 4
# Random number: 0.6774
# Decision: Exploitation
# Play with machine C
# Enter reward: 87
# Updated Q-value: 32.0
#
# Play 5
# Random number: 0.9937
# Decision: Exploitation
# Play with machine C
# Enter reward: 13
# Updated Q-value: 27.25
#
# Play 6
# Random number: 0.8987
# Decision: Exploitation
# Play with machine C
# Enter reward: 68
# Updated Q-value: 35.4
#
# Play 7
# Random number: 0.2044
# Decision: Exploitation
# Play with machine C
# Enter reward: 54
# Updated Q-value: 38.5
#
# Play 8
# Random number: 0.755
# Decision: Exploitation
# Play with machine C
# Enter reward: 67
# Updated Q-value: 42.5714
#
# Play 9
# Random number: 0.4953
# Decision: Exploitation
# Play with machine C
# Enter reward: 3
# Updated Q-value: 37.625
#
# Play 10
# Random number: 0.4948
# Decision: Exploitation
# Play with machine C
# Enter reward: 4
# Updated Q-value: 33.8889
#
# ====================================
# FINAL RESULTS
# ====================================
#
# Machine	N	R	Q
# A 	 0 	 0 	 0.0
# B 	 1 	 3.0 	 3.0
# C 	 9 	 305.0 	 33.89
#
# Total reward after 10 plays: 308.0
