# %%
# Greedy Multi-Armed Bandit using Arithmetic Mean

n = int(input("Enter number of machines: "))

machines = {}

for i in range(n):
    name = input(f"\nEnter machine name {i + 1}: ")
    rewards = list(map(float, input("Enter rewards separated by spaces: ").split()))
    machines[name] = rewards

q_values = {}

for name, rewards in machines.items():
    q_values[name] = sum(rewards) / len(rewards)

    print(f"\nMachine {name}")
    print(f"Rewards: {rewards}")
    print(f"Q({name}) = {q_values[name]:.2f}")

selected_machine = max(q_values, key=q_values.get)

print(f"\nGreedy Selected Machine: {selected_machine}")
# Out:
# Enter number of machines: 2
#
# Enter machine name 1: A
# Enter rewards separated by spaces: 4 7 6
#
# Enter machine name 2: B
# Enter rewards separated by spaces: 6 8 9
#
# Machine A
# Rewards: [4.0, 7.0, 6.0]
# Q(A) = 5.67
#
# Machine B
# Rewards: [6.0, 8.0, 9.0]
# Q(B) = 7.67
#
# Greedy Selected Machine: B

# %%
# Greedy Multi-Armed Bandit using Incremental Update

n = int(input("Enter number of machines: "))

machines = {}

# Take machine names and rewards
for i in range(n):
    name = input(f"\nEnter machine name {i + 1}: ")
    rewards = list(map(float, input("Enter rewards separated by spaces: ").split()))
    machines[name] = rewards

# Initialize Q and N
Q = {}
N = {}

for name in machines:
    Q[name] = 0
    N[name] = 0

# Process each reward
for name, rewards in machines.items():

    print(f"\nMachine {name}")

    for reward in rewards:
        # Increment number of plays
        N[name] += 1

        # Incremental update
        Q[name] = Q[name] + (reward - Q[name]) / N[name]

        print(
            f"Reward = {reward}, "
            f"N({name}) = {N[name]}, "
            f"Q({name}) = {Q[name]:.2f}"
        )

# Display final Q values
print("\nFinal Estimated Q Values:")

for name in machines:
    print(f"Q({name}) = {Q[name]:.2f}")

# Greedy selection
selected_machine = max(Q, key=Q.get)

print(f"\nGreedy Selected Machine: {selected_machine}")
# Out:
# Enter number of machines: 2
#
# Enter machine name 1: A
# Enter rewards separated by spaces: 3 7 5
#
# Enter machine name 2: B
# Enter rewards separated by spaces: 5 8 3
#
# Machine A
# Reward = 3.0, N(A) = 1, Q(A) = 3.00
# Reward = 7.0, N(A) = 2, Q(A) = 5.00
# Reward = 5.0, N(A) = 3, Q(A) = 5.00
#
# Machine B
# Reward = 5.0, N(B) = 1, Q(B) = 5.00
# Reward = 8.0, N(B) = 2, Q(B) = 6.50
# Reward = 3.0, N(B) = 3, Q(B) = 5.33
#
# Final Estimated Q Values:
# Q(A) = 5.00
# Q(B) = 5.33
#
# Greedy Selected Machine: B
